# %% [markdown]
# # Data Cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv('../data/raw/train_data.csv')
train_data
# Out:
#              brand  che_pc_usd  che_perc_gdp               cluster_nl  \
# 0       BRAND_354E    1.209114      1.665879  BRAND_354E_COUNTRY_88A3
# 1       BRAND_626D   -1.000000     -1.000000  BRAND_626D_COUNTRY_8B47
# 2       BRAND_45D9    1.209114      1.665879  BRAND_45D9_COUNTRY_88A3
# 3       BRAND_D724    1.851280      2.051770  BRAND_D724_COUNTRY_445D
# 4       BRAND_4887    1.791199      2.059130  BRAND_4887_COUNTRY_D8B0
# ...            ...         ...           ...                      ...
# 118912  BRAND_2058    2.074438      2.058055  BRAND_2058_COUNTRY_C8F4
# 118913  BRAND_4888    1.756234      1.819485  BRAND_4888_COUNTRY_6F78
# 118914  BRAND_0056    1.127497      1.491552  BRAND_0056_COUNTRY_0C7D
# 118915  BRAND_6200    1.874532      2.020277  BRAND_6200_COUNTRY_89F9
# 118916  BRAND_C21A    1.127497      1.491552  BRAND_C21A_COUNTRY_0C7D
#
#        corporation       country launch_date        date       drug_id  \
# 0        CORP_D524  COUNTRY_88A3  2014-06-01  2014-06-01  DRUG_ID_8795
# 1        CORP_01C7  COUNTRY_8B47  2014-06-01  2014-06-01  DRUG_ID_E66E
# 2        CORP_39F7  COUNTRY_88A3  2014-06-01  2014-06-01  DRUG_ID_F272
# 3        CORP_711A  COUNTRY_445D  2014-06-01  2014-06-01  DRUG_ID_1D4E
# 4        CORP_443D  COUNTRY_D8B0  2014-06-01  2014-06-01  DRUG_ID_AA88
# ...            ...           ...         ...         ...           ...
# 118912   CORP_3C9A  COUNTRY_C8F4  2020-11-01  2022-12-01  DRUG_ID_74A6
# 118913   CORP_A713  COUNTRY_6F78  2019-07-01  2022-12-01  DRUG_ID_52A5
# 118914   CORP_01C7  COUNTRY_0C7D  2018-09-01  2022-12-01  DRUG_ID_D637
# 118915   CORP_39F7  COUNTRY_89F9  2020-09-01  2022-12-01  DRUG_ID_B0E9
# 118916   CORP_C3C7  COUNTRY_0C7D  2021-05-01  2022-12-01  DRUG_ID_E2D9
#
#             ind_launch_date                indication  insurance_perc_che  \
# 0                        -1              ['IND_C3B6']            1.893333
# 1       2014-09-01 00:00:00  ['IND_1590', 'IND_ECAC']           -1.000000
# 2                        -1              ['IND_B2EF']            1.893333
# 3                        -1              ['IND_BAFB']            1.000000
# 4                        -1              ['IND_3F31']            2.013333
# ...                     ...                       ...                 ...
# 118912                   -1              ['IND_A496']           -1.000000
# 118913                   -1              ['IND_617C']            1.173333
# 118914                   -1              ['IND_FC21']            1.826667
# 118915  2020-11-01 00:00:00              ['IND_B2EF']           -1.000000
# 118916                   -1  ['IND_120F', 'IND_8E8D']            1.826667
#
#         population  prev_perc  price_month  price_unit  public_perc_che  \
# 0         1.008039   0.028367     1.006444    1.013784         1.835821
# 1         1.023562   0.000047    -1.000000    1.626677        -1.000000
# 2         1.008039   0.001502    -1.000000    3.144874         1.835821
# 3         1.253186   0.001304    -1.000000    1.213446         1.805970
# 4         1.639352   0.054467     1.018589    1.008708         1.880597
# ...            ...        ...          ...         ...              ...
# 118912    1.049808   0.095233     1.054007    1.100336         2.029851
# 118913    1.008985   0.033939     1.008317    1.029630         1.955224
# 118914    1.121505   0.012526     1.017259    1.018310         1.926795
# 118915    1.520144   0.001334     1.960978    2.490911         1.985847
# 118916    1.121505   0.041152    -1.000000    1.002689         1.926795
#
#        therapeutic_area    target
# 0        THER_AREA_980E  1.000784
# 1        THER_AREA_96D7  1.000000
# 2        THER_AREA_96D7  1.002258
# 3        THER_AREA_6CEE  1.068761
# 4        THER_AREA_6CEE  1.036312
# ...                 ...       ...
# 118912   THER_AREA_6CEE  1.203657
# 118913   THER_AREA_980E  1.109272
# 118914   THER_AREA_644A  1.343341
# 118915   THER_AREA_96D7  1.266831
# 118916   THER_AREA_CD59  1.001763
#
# [118917 rows x 19 columns]

# %%
train_data.replace(-1, np.nan, inplace=True)
train_data.replace("-1", np.nan, inplace=True)
train_data
# Out:
#              brand  che_pc_usd  che_perc_gdp               cluster_nl  \
# 0       BRAND_354E    1.209114      1.665879  BRAND_354E_COUNTRY_88A3
# 1       BRAND_626D         NaN           NaN  BRAND_626D_COUNTRY_8B47
# 2       BRAND_45D9    1.209114      1.665879  BRAND_45D9_COUNTRY_88A3
# 3       BRAND_D724    1.851280      2.051770  BRAND_D724_COUNTRY_445D
# 4       BRAND_4887    1.791199      2.059130  BRAND_4887_COUNTRY_D8B0
# ...            ...         ...           ...                      ...
# 118912  BRAND_2058    2.074438      2.058055  BRAND_2058_COUNTRY_C8F4
# 118913  BRAND_4888    1.756234      1.819485  BRAND_4888_COUNTRY_6F78
# 118914  BRAND_0056    1.127497      1.491552  BRAND_0056_COUNTRY_0C7D
# 118915  BRAND_6200    1.874532      2.020277  BRAND_6200_COUNTRY_89F9
# 118916  BRAND_C21A    1.127497      1.491552  BRAND_C21A_COUNTRY_0C7D
#
#        corporation       country launch_date        date       drug_id  \
# 0        CORP_D524  COUNTRY_88A3  2014-06-01  2014-06-01  DRUG_ID_8795
# 1        CORP_01C7  COUNTRY_8B47  2014-06-01  2014-06-01  DRUG_ID_E66E
# 2        CORP_39F7  COUNTRY_88A3  2014-06-01  2014-06-01  DRUG_ID_F272
# 3        CORP_711A  COUNTRY_445D  2014-06-01  2014-06-01  DRUG_ID_1D4E
# 4        CORP_443D  COUNTRY_D8B0  2014-06-01  2014-06-01  DRUG_ID_AA88
# ...            ...           ...         ...         ...           ...
# 118912   CORP_3C9A  COUNTRY_C8F4  2020-11-01  2022-12-01  DRUG_ID_74A6
# 118913   CORP_A713  COUNTRY_6F78  2019-07-01  2022-12-01  DRUG_ID_52A5
# 118914   CORP_01C7  COUNTRY_0C7D  2018-09-01  2022-12-01  DRUG_ID_D637
# 118915   CORP_39F7  COUNTRY_89F9  2020-09-01  2022-12-01  DRUG_ID_B0E9
# 118916   CORP_C3C7  COUNTRY_0C7D  2021-05-01  2022-12-01  DRUG_ID_E2D9
#
#             ind_launch_date                indication  insurance_perc_che  \
# 0                       NaN              ['IND_C3B6']            1.893333
# 1       2014-09-01 00:00:00  ['IND_1590', 'IND_ECAC']                 NaN
# 2                       NaN              ['IND_B2EF']            1.893333
# 3                       NaN              ['IND_BAFB']            1.000000
# 4                       NaN              ['IND_3F31']            2.013333
# ...                     ...                       ...                 ...
# 118912                  NaN              ['IND_A496']                 NaN
# 118913                  NaN              ['IND_617C']            1.173333
# 118914                  NaN              ['IND_FC21']            1.826667
# 118915  2020-11-01 00:00:00              ['IND_B2EF']                 NaN
# 118916                  NaN  ['IND_120F', 'IND_8E8D']            1.826667
#
#         population  prev_perc  price_month  price_unit  public_perc_che  \
# 0         1.008039   0.028367     1.006444    1.013784         1.835821
# 1         1.023562   0.000047          NaN    1.626677              NaN
# 2         1.008039   0.001502          NaN    3.144874         1.835821
# 3         1.253186   0.001304          NaN    1.213446         1.805970
# 4         1.639352   0.054467     1.018589    1.008708         1.880597
# ...            ...        ...          ...         ...              ...
# 118912    1.049808   0.095233     1.054007    1.100336         2.029851
# 118913    1.008985   0.033939     1.008317    1.029630         1.955224
# 118914    1.121505   0.012526     1.017259    1.018310         1.926795
# 118915    1.520144   0.001334     1.960978    2.490911         1.985847
# 118916    1.121505   0.041152          NaN    1.002689         1.926795
#
#        therapeutic_area    target
# 0        THER_AREA_980E  1.000784
# 1        THER_AREA_96D7  1.000000
# 2        THER_AREA_96D7  1.002258
# 3        THER_AREA_6CEE  1.068761
# 4        THER_AREA_6CEE  1.036312
# ...                 ...       ...
# 118912   THER_AREA_6CEE  1.203657
# 118913   THER_AREA_980E  1.109272
# 118914   THER_AREA_644A  1.343341
# 118915   THER_AREA_96D7  1.266831
# 118916   THER_AREA_CD59  1.001763
#
# [118917 rows x 19 columns]

# %%
variables = train_data.columns
print(f"There are {len(variables)} variables in the dataset and {len(train_data)} rows.")
variables
# Out:
# There are 19 variables in the dataset and 118917 rows.
# Index(['brand', 'che_pc_usd', 'che_perc_gdp', 'cluster_nl', 'corporation',
#        'country', 'launch_date', 'date', 'drug_id', 'ind_launch_date',
#        'indication', 'insurance_perc_che', 'population', 'prev_perc',
#        'price_month', 'price_unit', 'public_perc_che', 'therapeutic_area',
#        'target'],
#       dtype='object')

# %%
na_counts = train_data.isna().sum()
na_percentage = (na_counts / len(train_data)) * 100
print(na_percentage)
# Out:
# brand                  0.000000
# che_pc_usd             0.623124
# che_perc_gdp           3.064322
# cluster_nl             0.000000
# corporation            0.000000
# country                0.000000
# launch_date            0.000000
# date                   0.000000
# drug_id                0.000000
# ind_launch_date       73.830487
# indication             0.000000
# insurance_perc_che    19.500996
# population             0.000000
# prev_perc              0.000000
# price_month           20.309964
# price_unit             0.200981
# public_perc_che        0.623124
# therapeutic_area       0.000000
# target                 0.000000
# dtype: float64

# %%
vars_to_remove = ['cluster_nl', 'ind_launch_date']
train_data.drop(vars_to_remove, axis = 1, inplace = True)

# %%
# Convertir las columnas 'date' y 'launch_date' a formato de fecha
train_data['date'] = pd.to_datetime(train_data['date'])
train_data['launch_date'] = pd.to_datetime(train_data['launch_date'])

# Calcular la diferencia de tiempo en meses
train_data['time_difference'] = (train_data['date'] - train_data['launch_date']) / np.timedelta64(1, 'M')

# Mostrar las primeras filas para verificar
train_data[['date', 'launch_date', 'time_difference']].head()
# Out:
#         date launch_date  time_difference
# 0 2014-06-01  2014-06-01              0.0
# 1 2014-06-01  2014-06-01              0.0
# 2 2014-06-01  2014-06-01              0.0
# 3 2014-06-01  2014-06-01              0.0
# 4 2014-06-01  2014-06-01              0.0

# %%
from sklearn.impute import KNNImputer

# Initialize the KNNImputer with k=7
imputer = KNNImputer(n_neighbors=7)
numerical_vars = train_data.select_dtypes(include=[np.number]).columns

# Impute the missing values
train_data_imputed = pd.DataFrame(imputer.fit_transform(train_data.select_dtypes(include=[np.number])), columns=numerical_vars)

# Assign the imputed values back to the original dataframe
train_data[numerical_vars] = train_data_imputed

# Display the imputed dataframe
train_data
# Out:
#              brand  che_pc_usd  che_perc_gdp corporation       country  \
# 0       BRAND_354E    1.209114      1.665879   CORP_D524  COUNTRY_88A3
# 1       BRAND_626D    1.942126      1.834245   CORP_01C7  COUNTRY_8B47
# 2       BRAND_45D9    1.209114      1.665879   CORP_39F7  COUNTRY_88A3
# 3       BRAND_D724    1.851280      2.051770   CORP_711A  COUNTRY_445D
# 4       BRAND_4887    1.791199      2.059130   CORP_443D  COUNTRY_D8B0
# ...            ...         ...           ...         ...           ...
# 118912  BRAND_2058    2.074438      2.058055   CORP_3C9A  COUNTRY_C8F4
# 118913  BRAND_4888    1.756234      1.819485   CORP_A713  COUNTRY_6F78
# 118914  BRAND_0056    1.127497      1.491552   CORP_01C7  COUNTRY_0C7D
# 118915  BRAND_6200    1.874532      2.020277   CORP_39F7  COUNTRY_89F9
# 118916  BRAND_C21A    1.127497      1.491552   CORP_C3C7  COUNTRY_0C7D
#
#        launch_date       date       drug_id                indication  \
# 0       2014-06-01 2014-06-01  DRUG_ID_8795              ['IND_C3B6']
# 1       2014-06-01 2014-06-01  DRUG_ID_E66E  ['IND_1590', 'IND_ECAC']
# 2       2014-06-01 2014-06-01  DRUG_ID_F272              ['IND_B2EF']
# 3       2014-06-01 2014-06-01  DRUG_ID_1D4E              ['IND_BAFB']
# 4       2014-06-01 2014-06-01  DRUG_ID_AA88              ['IND_3F31']
# ...            ...        ...           ...                       ...
# 118912  2020-11-01 2022-12-01  DRUG_ID_74A6              ['IND_A496']
# 118913  2019-07-01 2022-12-01  DRUG_ID_52A5              ['IND_617C']
# 118914  2018-09-01 2022-12-01  DRUG_ID_D637              ['IND_FC21']
# 118915  2020-09-01 2022-12-01  DRUG_ID_B0E9              ['IND_B2EF']
# 118916  2021-05-01 2022-12-01  DRUG_ID_E2D9  ['IND_120F', 'IND_8E8D']
#
#         insurance_perc_che  population  prev_perc  price_month  price_unit  \
# 0                 1.893333    1.008039   0.028367     1.006444    1.013784
# 1                 1.175238    1.023562   0.000047     1.651364    1.626677
# 2                 1.893333    1.008039   0.001502     8.309454    3.144874
# 3                 1.000000    1.253186   0.001304     1.352545    1.213446
# 4                 2.013333    1.639352   0.054467     1.018589    1.008708
# ...                    ...         ...        ...          ...         ...
# 118912            1.604854    1.049808   0.095233     1.054007    1.100336
# 118913            1.173333    1.008985   0.033939     1.008317    1.029630
# 118914            1.826667    1.121505   0.012526     1.017259    1.018310
# 118915            1.432381    1.520144   0.001334     1.960978    2.490911
# 118916            1.826667    1.121505   0.041152     1.021014    1.002689
#
#         public_perc_che therapeutic_area    target  time_difference
# 0              1.835821   THER_AREA_980E  1.000784         0.000000
# 1              1.855011   THER_AREA_96D7  1.000000         0.000000
# 2              1.835821   THER_AREA_96D7  1.002258         0.000000
# 3              1.805970   THER_AREA_6CEE  1.068761         0.000000
# 4              1.880597   THER_AREA_6CEE  1.036312         0.000000
# ...                 ...              ...       ...              ...
# 118912         2.029851   THER_AREA_6CEE  1.203657        24.516129
# 118913         1.955224   THER_AREA_980E  1.109272        40.290323
# 118914         1.926795   THER_AREA_644A  1.343341        50.064516
# 118915         1.985847   THER_AREA_96D7  1.266831        26.483871
# 118916         1.926795   THER_AREA_CD59  1.001763        18.677419
#
# [118917 rows x 18 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_data[numerical_vars] = scaler.fit_transform(train_data[numerical_vars])

# %%
train_data.to_csv('../data/processed/train_data_processed.csv', index=False)
